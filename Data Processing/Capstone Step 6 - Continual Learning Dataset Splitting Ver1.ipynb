# %%
import pandas as pd
import numpy as np
import random
from pandas import DataFrame
try:
    import cPickle as pickle
except ImportError:
    import _pickle as pickle

# %%
#Import datasets into dataframes
below65 = pd.read_csv('C:\\Users\\sara1\\Desktop\\Workingdata\\rl_below65_final_cont_noterm.csv')
above65 = pd.read_csv('C:\\Users\\sara1\\Desktop\\Workingdata\\rl_above65_final_cont_noterm.csv')

# %%
#Display the columns
below65.head()
# Out:
#     stay_id  sofa_score  sirs       age    weight  gender  gcs  sofa_24hours  \
# 0  38563000         0.0   1.0  0.425532  0.107514     1.0  1.0      0.043478
# 1  38563000         0.0   1.0  0.425532  0.107514     1.0  1.0      0.086957
# 2  38563000         0.0   1.0  0.425532  0.107514     1.0  1.0      0.173913
# 3  38563000         0.0   1.0  0.425532  0.107514     1.0  1.0      0.043478
# 4  38563000         0.0   1.0  0.425532  0.107514     1.0  1.0      0.086957
#
#    bilirubin_total  bicarbonate  ...  creatinine  heart_rate  temperature  \
# 0         0.065682          NaN  ...    0.105287    0.506438     0.563117
# 1         0.065682          NaN  ...    0.105287    0.506438     0.563117
# 2         0.065682          NaN  ...    0.105287    0.506438     0.563117
# 3         0.065682          NaN  ...    0.105287    0.506438     0.563117
# 4         0.065682          NaN  ...    0.105287    0.506438     0.563117
#
# ...

# %%
#Display the columns
above65.head()
# Out:
#     stay_id  sofa_score  sirs       age    weight  gender       gcs  \
# 0  34712382    0.277778  0.75  1.553191  0.048170     0.0  0.916667
# 1  34712382    0.277778  0.75  1.553191  0.048170     0.0  0.916667
# 2  34712382    0.277778  0.75  1.553191  0.048170     0.0  0.916667
# 3  34712382    0.277778  0.75  1.553191  0.048170     0.0  0.916667
# 4  30902754    0.000000  1.00  1.468085  0.104046     1.0  0.416667
#
#    sofa_24hours  bilirubin_total  bicarbonate  ...  creatinine  heart_rate  \
# 0      0.304348         0.065682          NaN  ...    0.179487    0.218884
# 1      0.304348         0.065682          NaN  ...    0.179487    0.218884
# 2      0.304348         0.065682          NaN  ...    0.179487    0.218884
# 3      0.304348         0.065682          NaN  ...    0.179487    0.218884
# 4      0.043478         0.065682          NaN  ...    0.017094    0.476395
#
#    temperature      spo2  vaso_rate  vaso_amount  urineoutput  died_in_hosp  \
# ...

# %%
#Replace the singular value in bicarbonate with random numbers from max and min val
column_name = 'bicarbonate'

# Generate random numbers within the specified range
min_value = 20
max_value = 36
random_numbers_below65 = np.random.randint(min_value, max_value + 1, size=len(below65))
random_numbers_above65 = np.random.randint(min_value, max_value + 1, size=len(above65))

# Replace values in the column with random numbers
below65[column_name] = random_numbers_below65
above65[column_name] = random_numbers_above65

# %%
# now split into train/validation/test sets for below 65 dataset
unique_ids_below65 = below65['stay_id'].unique()
random.shuffle(unique_ids_below65)
train_sample_below65 = 0.7
val_sample_below65 = 0.1
test_sample_below65 = 0.2
train_num_below65 = int(len(unique_ids_below65) * 0.7)
val_num_below65 = int(len(unique_ids_below65)*0.1) + train_num_below65
train_ids_below65 = unique_ids_below65[:train_num_below65]
val_ids_below65 = unique_ids_below65[train_num_below65:val_num_below65]
test_ids_below65 = unique_ids_below65[val_num_below65:]

# %%
#Put them into dataframes for below 65 dataset
train_set_below65 = DataFrame()
train_set_below65 = below65.loc[below65['stay_id'].isin(train_ids_below65)]

val_set_below65 = DataFrame()
val_set_below65 = below65.loc[below65['stay_id'].isin(val_ids_below65)]

test_set_below65 = DataFrame()
test_set_below65 = below65.loc[below65['stay_id'].isin(test_ids_below65)]

# %%
av_below65 = train_set_below65[column_name].mean()
std_below65 = train_set_below65[column_name].std()
train_set_below65[column_name] = (train_set_below65[column_name] - av_below65) / std_below65
val_set_below65[column_name] = (val_set_below65[column_name] - av_below65) / std_below65
test_set_below65[column_name] = (test_set_below65[column_name] - av_below65) / std_below65
# Out:
# C:\Users\sara1\AppData\Local\Temp/ipykernel_2820/880624015.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_set_below65[column_name] = (train_set_below65[column_name] - av_below65) / std_below65
# C:\Users\sara1\AppData\Local\Temp/ipykernel_2820/880624015.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_set_below65[column_name] = (val_set_below65[column_name] - av_below65) / std_below65
# ...

# %%
#Scale the datasets for below 65
minimum_below65 = min(train_set_below65[column_name])
maximum_below65 = max(train_set_below65[column_name])
train_set_below65[column_name] = (train_set_below65[column_name] - minimum_below65)/(maximum_below65-minimum_below65)
val_set_below65[column_name] = (val_set_below65[column_name] - minimum_below65)/(maximum_below65-minimum_below65)
test_set_below65[column_name] = (test_set_below65[column_name] - minimum_below65)/(maximum_below65-minimum_below65)
# Out:
# C:\Users\sara1\AppData\Local\Temp/ipykernel_2820/705239287.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_set_below65[column_name] = (train_set_below65[column_name] - minimum_below65)/(maximum_below65-minimum_below65)
# C:\Users\sara1\AppData\Local\Temp/ipykernel_2820/705239287.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_set_below65[column_name] = (val_set_below65[column_name] - minimum_below65)/(maximum_below65-minimum_below65)
# ...

# %%
train_set_below65.head()
# Out:
#     stay_id  sofa_score  sirs       age    weight  gender  gcs  sofa_24hours  \
# 0  38563000         0.0   1.0  0.425532  0.107514     1.0  1.0      0.043478
# 1  38563000         0.0   1.0  0.425532  0.107514     1.0  1.0      0.086957
# 2  38563000         0.0   1.0  0.425532  0.107514     1.0  1.0      0.173913
# 3  38563000         0.0   1.0  0.425532  0.107514     1.0  1.0      0.043478
# 4  38563000         0.0   1.0  0.425532  0.107514     1.0  1.0      0.086957
#
#    bilirubin_total  bicarbonate  ...  creatinine  heart_rate  temperature  \
# 0         0.065682       0.8125  ...    0.105287    0.506438     0.563117
# 1         0.065682       0.3750  ...    0.105287    0.506438     0.563117
# 2         0.065682       0.0000  ...    0.105287    0.506438     0.563117
# 3         0.065682       0.3125  ...    0.105287    0.506438     0.563117
# 4         0.065682       0.3750  ...    0.105287    0.506438     0.563117
#
# ...

# %%
val_set_below65.head()
# Out:
#        stay_id  sofa_score  sirs       age    weight  gender  gcs  \
# 9768  39103890         0.0   1.0  0.787234  0.175337     1.0  0.0
# 9769  39103890         0.0   1.0  0.787234  0.175337     1.0  0.0
# 9770  39103890         0.0   1.0  0.787234  0.175337     1.0  0.0
# 9771  39103890         0.0   1.0  0.787234  0.175337     1.0  0.0
# 9772  39103890         0.0   1.0  0.787234  0.175337     1.0  0.0
#
#       sofa_24hours  bilirubin_total  bicarbonate  ...  creatinine  heart_rate  \
# 9768      0.086957         0.065682       1.0000  ...    0.105287    0.422394
# 9769      0.347826         0.065682       0.1250  ...    0.105287    0.422394
# 9770      0.434783         0.065682       0.0000  ...    0.105287    0.422394
# 9771      0.478261         0.065682       0.5625  ...    0.105287    0.422394
# 9772      0.652174         0.065682       0.8125  ...    0.105287    0.422394
#
#       temperature      spo2  vaso_rate  vaso_amount  urineoutput  \
# ...

# %%
test_set_below65.head()
# Out:
#        stay_id  sofa_score  sirs      age    weight  gender  gcs  \
# 1452  31196251    0.055556   1.0  0.87234  0.081888     1.0  0.0
# 1453  31196251    0.055556   1.0  0.87234  0.081888     1.0  0.0
# 1454  31196251    0.055556   1.0  0.87234  0.081888     1.0  0.0
# 1455  31196251    0.055556   1.0  0.87234  0.081888     1.0  0.0
# 1456  31196251    0.055556   1.0  0.87234  0.081888     1.0  0.0
#
#       sofa_24hours  bilirubin_total  bicarbonate  ...  creatinine  heart_rate  \
# 1452      0.000000         0.065682       0.1250  ...    0.105287    0.570815
# 1453      0.043478         0.065682       0.7500  ...    0.105287    0.570815
# 1454      0.086957         0.065682       0.9375  ...    0.105287    0.570815
# 1455      0.130435         0.065682       0.9375  ...    0.105287    0.570815
# 1456      0.173913         0.065682       0.4375  ...    0.105287    0.570815
#
#       temperature      spo2  vaso_rate  vaso_amount  urineoutput  \
# ...

# %%
#Save the csv
train_set_below65.to_csv('C:\\Users\\sara1\\Desktop\\Workingdata\\rl_train_below65.csv',index = False)
val_set_below65.to_csv('C:\\Users\\sara1\\Desktop\\Workingdata\\rl_val_below65.csv',index = False)
test_set_below65.to_csv('C:\\Users\\sara1\\Desktop\\Workingdata\\rl_test_below65.csv',index = False)

# %%
# now split into train/validation/test sets for above 65 dataset
unique_ids_above65 = above65['stay_id'].unique()
random.shuffle(unique_ids_above65)
train_sample_above65 = 0.7
val_sample_above65 = 0.1
test_sample_above65 = 0.2
train_num_above65 = int(len(unique_ids_above65) * 0.7)
val_num_above65 = int(len(unique_ids_above65)*0.1) + train_num_above65
train_ids_above65 = unique_ids_above65[:train_num_above65]
val_ids_above65 = unique_ids_above65[train_num_above65:val_num_above65]
test_ids_above65 = unique_ids_above65[val_num_above65:]

# %%
#Put them into dataframes for above 65 dataset
train_set_above65 = DataFrame()
train_set_above65 = above65.loc[above65['stay_id'].isin(train_ids_above65)]

val_set_above65 = DataFrame()
val_set_above65 = above65.loc[above65['stay_id'].isin(val_ids_above65)]

test_set_above65 = DataFrame()
test_set_above65 = above65.loc[above65['stay_id'].isin(test_ids_above65)]

# %%
av_above65 = train_set_above65[column_name].mean()
std_above65 = train_set_above65[column_name].std()
train_set_above65[column_name] = (train_set_above65[column_name] - av_above65) / std_above65
val_set_above65[column_name] = (val_set_above65[column_name] - av_above65) / std_above65
test_set_above65[column_name] = (test_set_above65[column_name] - av_above65) / std_above65
# Out:
# C:\Users\sara1\AppData\Local\Temp/ipykernel_2820/2828362392.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_set_above65[column_name] = (train_set_above65[column_name] - av_above65) / std_above65
# C:\Users\sara1\AppData\Local\Temp/ipykernel_2820/2828362392.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_set_above65[column_name] = (val_set_above65[column_name] - av_above65) / std_above65
# ...

# %%
#Scale the datasets for above 65
minimum_above65 = min(train_set_above65[column_name])
maximum_above65 = max(train_set_above65[column_name])
train_set_above65[column_name] = (train_set_above65[column_name] - minimum_above65)/(maximum_above65-minimum_above65)
val_set_above65[column_name] = (val_set_above65[column_name] - minimum_above65)/(maximum_above65-minimum_above65)
test_set_above65[column_name] = (test_set_above65[column_name] - minimum_above65)/(maximum_above65-minimum_above65)
# Out:
# C:\Users\sara1\AppData\Local\Temp/ipykernel_2820/1883650119.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_set_above65[column_name] = (train_set_above65[column_name] - minimum_above65)/(maximum_above65-minimum_above65)
# C:\Users\sara1\AppData\Local\Temp/ipykernel_2820/1883650119.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   val_set_above65[column_name] = (val_set_above65[column_name] - minimum_above65)/(maximum_above65-minimum_above65)
# ...

# %%
train_set_above65.head()
# Out:
#     stay_id  sofa_score  sirs       age    weight  gender       gcs  \
# 4  30902754         0.0   1.0  1.468085  0.104046     1.0  0.416667
# 5  30902754         0.0   1.0  1.468085  0.104046     1.0  0.416667
# 6  30902754         0.0   1.0  1.468085  0.104046     1.0  0.416667
# 7  30902754         0.0   1.0  1.468085  0.104046     1.0  0.416667
# 8  30902754         0.0   1.0  1.468085  0.104046     1.0  0.416667
#
#    sofa_24hours  bilirubin_total  bicarbonate  ...  creatinine  heart_rate  \
# 4      0.043478         0.065682       0.5625  ...    0.017094    0.476395
# 5      0.086957         0.065682       0.3750  ...    0.017094    0.476395
# 6      0.130435         0.065682       0.1250  ...    0.017094    0.476395
# 7      0.173913         0.065682       0.0000  ...    0.017094    0.476395
# 8      0.217391         0.065682       0.2500  ...    0.017094    0.476395
#
#    temperature      spo2  vaso_rate  vaso_amount  urineoutput  died_in_hosp  \
# ...

# %%
val_set_above65.head()
# Out:
#        stay_id  sofa_score  sirs       age    weight  gender       gcs  \
# 9145  31301788         0.0   0.5  1.382979  0.073218     0.0  0.416667
# 9146  31301788         0.0   0.5  1.382979  0.073218     0.0  0.416667
# 9147  31301788         0.0   0.5  1.382979  0.073218     0.0  0.416667
# 9148  31301788         0.0   0.5  1.382979  0.073218     0.0  0.416667
# 9149  31301788         0.0   0.5  1.382979  0.073218     0.0  0.416667
#
#       sofa_24hours  bilirubin_total  bicarbonate  ...  creatinine  heart_rate  \
# 9145      0.086957         0.065682        0.750  ...    0.059829    0.540773
# 9146      0.130435         0.065682        0.375  ...    0.059829    0.540773
# 9147      0.173913         0.065682        0.875  ...    0.059829    0.540773
# 9148      0.217391         0.065682        1.000  ...    0.059829    0.540773
# 9149      0.260870         0.065682        0.750  ...    0.059829    0.540773
#
#       temperature      spo2  vaso_rate  vaso_amount  urineoutput  \
# ...

# %%
test_set_above65.head()
# Out:
#        stay_id  sofa_score  sirs       age    weight  gender       gcs  \
# 0     34712382    0.277778  0.75  1.553191  0.048170     0.0  0.916667
# 1     34712382    0.277778  0.75  1.553191  0.048170     0.0  0.916667
# 2     34712382    0.277778  0.75  1.553191  0.048170     0.0  0.916667
# 3     34712382    0.277778  0.75  1.553191  0.048170     0.0  0.916667
# 8137  31494077    0.055556  0.75  1.063830  0.131021     1.0  1.000000
#
#       sofa_24hours  bilirubin_total  bicarbonate  ...  creatinine  heart_rate  \
# 0         0.304348         0.065682       0.8125  ...    0.179487    0.218884
# 1         0.304348         0.065682       0.1250  ...    0.179487    0.218884
# 2         0.304348         0.065682       0.7500  ...    0.179487    0.218884
# 3         0.304348         0.065682       1.0000  ...    0.179487    0.218884
# 8137      0.000000         0.065682       0.5000  ...    0.105287    0.618026
#
#       temperature      spo2  vaso_rate  vaso_amount  urineoutput  \
# ...

# %%
#Save the csv
train_set_above65.to_csv('C:\\Users\\sara1\\Desktop\\Workingdata\\rl_train_above65.csv',index = False)
val_set_above65.to_csv('C:\\Users\\sara1\\Desktop\\Workingdata\\rl_val_above65.csv',index = False)
test_set_above65.to_csv('C:\\Users\\sara1\\Desktop\\Workingdata\\rl_test_above65.csv',index = False)
